# %%
import pandas as pd

df = pd.read_csv("json_test.csv")

# %%
course_names = df['description']

# %%
course_names[0]
# Out:
# 'Advanced Animal Science (AG1AA)'

# %%
list(course_names.values)
# Out:
# ['Advanced Animal Science (AG1AA)',
#  'Advanced Animal Science (AG1AA)',
#  'Equine Science (AG1EQ)',
#  'Equine Science (AG1EQ)',
#  'Floral Design (AG1FL)',
#  'Floral Design (AG1FL)',
#  'Prin Agric, Food, Natural Res (AG1FN)',
#  'Prin Agric, Food, Natural Res (AG1FN)',
#  'Livestock Production (AG1LP)',
#  'Livestock Production (AG1LP)',
#  'Ag Mechanical-Metal Technology (AG1MM)',
#  'Ag Mechanica-Metal Technology (AG1MM)',
#  'Math Applications Agriculture (AG1MT)',
#  'Math Applications Agriculture (AG1MT)',
#  'Practicum-Ag-Mechanics (AG1PM)',
#  'Practicum-Ag-Mechanics (AG1PM)',
#  'Small Animal Management (AG1SA)',
#  'Small Animal Management (AG1SA)',
#  'Agricultrual Structure DesFab (AG1SD)',
#  'Agricultrual Structure DesFab (AG1SD)',
#  'Prac Ag-Veterinary Med (AG2PA)',
#  'Prac Ag-Veterinary Med (AG2PA)',
#  'Prac-Ag-Floral Design I (AG2PF)',
#  'Prac-Ag-Floral Design I (AG2PF)',
#  'Veterinary Medical Application (AG2VM)',
#  'Veterinary Medical Application (AG2VM)',
#  'Advance Music Band 10th (AM2BP)',
#  'Advance Music Band 10th (AM2BP)',
#  'Advance Music Choir 10th (AM2CP)',
#  'Advance Music Choir 10th (AM2CP)',
#  'Advance Music Orchestra 10th (AM2OP)',
#  'Advance Music Orchestra 10th (AM2OP)',
#  'Advance Music Band 11th (AM3BJ)',
#  'Advance Music Band 11th (AM3BJ)',
#  'Advance Music Band 12th (AM3BS)',
#  'Advance Music Band 12th (AM3BS)',
#  'Advance Music Choir 11th (AM3CJ)',
#  'Advance Music Choir 11th (AM3CJ)',
#  'Advance Music Choir 12th (AM3CS)',
#  'Advance Music Choir 12th (AM3CS)',
#  'Advance Music Orchestra 11th (AM3OJ)',
#  'Advance Music Orchestra 11th (AM3OJ)',
#  'Advance Music Orchestra 12th (AM3OS)',
#  'Advance Music Orchestra 12th (AM3OS)',
#  'Accounting I (BM1AC)',
#  'Accounting I (BM1AC)',
#  'Advertising (BM1AD)',
#  'Banking and Financial Services (BM1BF)',
#  'Banking and Financial Services (BM1BF)',
#  'Business Management (BM1BM)',
#  'Business Management (BM1BM)',
#  'Entrepreneurship (BM1EP)',
#  'Entrepreneurship (BM1EP)',
#  'Financial Mathematics (BM1FI)',
#  'Financial Mathematics (BM1FI)',
#  'Fashion Marketing (BM1FM)',
#  'Business Information Mgt I (BM1I1)',
#  'Business Information Mgt I (BM1I1)',
#  'Business Information Mgt II (BM1I2)',
#  'Business Information Mgt II (BM1I2)',
#  'Business Law (BM1LW)',
#  'Business Law (BM1LW)',
#  'Practicum in Business Mgt I (BM1PB)',
#  'Practicum in Business Mgt I (BM1PB)',
#  'Pri Business\\/Marketing\\/Finance (BM1PM)',
#  'Pri Business\\/Marketing\\/Finance (BM1PM)',
#  'Sports Entertainment Marketing (BM1SE)',
#  'Sports Entertainment Marketing (BM1SE)',
#  'Prac Business - Financial Serv (BM2PF)',
#  'Prac Business Financial Serv (BM2PF)',
#  'DC Prin Financial Accounting (BM5AC)',
#  'DC Prin Managerial Accounting (BM5AC)',
#  'DC Bus & Prof Communication (BM5BC)',
#  'DC Bus & Prof Communication (BM5BC)',
#  'DC Bus & Prof Communication (BM5BC)',
#  'DC Bus & Prof Communication (BM5BC)',
#  'DC Business Principles (BM5BP)',
#  'DC Business Principles (BM5BP)',
#  'DC Business Principles (BM5BP)',
#  'DC Business Principles (BM5BP)',
#  'DC Business Principles (BM5BP)',
#  'DC Business Principles (BM5BP)',
#  'Dollars & Sense (BM9DS)',
#  'Money Matters (BM9MM)',
#  'Money Matters (BM9MM)',
#  'Practicum Business Mgmt II (BMPB2)',
#  'Practicum Business Mgmt II (BMPB2)',
#  'Debate 1 (CO1D1)',
#  'Debate 1 (CO1D1)',
#  'Debate II (CO1D2)',
#  'Debate II (CO1D2)',
#  'Journalism (CO1JR)',
#  'Journalism (CO1JR)',
#  'Advanced Journalism News (CO1N1)',
#  'Advanced Journalism News (CO1N1)',
#  'Advanced Journalism News 2 (CO1N2)',
#  'Advanced Journalism News 2 (CO1N2)',
#  'Advanced Journalism News 3 (CO1N3)',
#  'Advanced Journalism News 3 (CO1N3)',
#  'Advanced Journalism Yearbook (CO1Y1)',
#  'Advanced Journalism Yearbook (CO1Y1)',
#  'Advanced Journalism Yearbook 2 (CO1Y2)',
#  'Advanced Journalism Yearbook 2 (CO1Y2)',
#  'Advanced Journalism Yearbook 3 (CO1Y3)',
#  'Advanced Journalism Yearbook 3 (CO1Y3)',
#  'Independent Study Journalism 2 (CO2I2)',
#  'Independent Study Journalism 2 (CO2I2)',
#  'Independent Study Journalism 3 (CO2I3)',
#  'Independent Study Journalism 3 (CO2I3)',
#  'Independent Study Journalism 1 (CO2IS)',
#  'Independent Study Journalism (CO2IS)',
#  'Advanced JournalismNews 2 Edit (CO2N2)',
#  'Advanced JournalismNews 2 Edit (CO2N2)',
#  'Advanced JournalismNews 3 Edit (CO2N3)',
#  'Advanced JournalismNews 3 Edit (CO2N3)',
#  'Advanced Journalism Yrbk2 Edit (CO2Y2)',
#  'Advanced Journalism Yrbk2 Edit (CO2Y2)',
#  'Advanced Journalism Yrbk3 Edit (CO2Y3)',
#  'Advanced Journalism Yrbk3 Edit (CO2Y3)',
#  'DC Intro to Speech Comm (CO5CA)',
#  'DC Intro to Speech Comm (CO5CA)',
#  'DC Intro to Speech Comm (CO5CA)',
#  'DC Intro to Speech Comm (CO5CA)',
#  'DC Intro to Speech Comm (CO5CA)',
#  'DC Bus & Prof Communication (CO5PB)',
#  'DC Bus & Prof Communication (CO5PB)',
#  'DC Bus & Prof Communication (CO5PB)',
#  'DC Bus & Prof Communication (CO5PB)',
#  'DC Bus & Prof Communication (CO5PB)',
#  'DC Public Speaking (CO5SP)',
#  'DC Public Speaking (CO5SP)',
#  'DC Public Speaking (CO5SP)',
#  'DC Public Speaking (CO5SP)',
#  'Aquatic Science (CX1AQ)',
#  'Aquatic Science (CX1AQ)',
#  'Chemistry M (CX1CH)',
#  'Chemistry M (CX1CH)',
#  'Environmental Science (CX1EN)',
#  'Environmental Science (CX1EN)',
#  'IPC Modified (CX1PI)',
#  'IPC Modified (CX1PI)',
#  'Chemistry ESS (CX9CH)',
#  'Chemistry ESS (CX9CH)',
#  'Environmental Systems Applied (CY9B3)',
#  'Environmental Systems Applied (CY9B3)',
#  'Aquatic Science Applied (CY9B4)',
#  'Aquatic Science Applied (CY9B4)',
#  'Biology APP (CY9IB)',
#  'Biology APP (CY9IB)',
#  'IPC APP (CY9IP)',
#  'IPC APP (CY9IP)',
#  'SAT-ACT Prep Class (EL1SA)',
#  'SAT-ACT Prep Class (EL1SA)',
#  'Study Skills BASIC (EL9BS)',
#  'Study Skills BASIC (EL9BS)',
#  'Making Connections II (EL9C2)',
#  'Making Connections II (EL9C2)',
#  'Making Connections III (EL9C3)',
#  'Making Connections III (EL9C3)',
#  'Making Connections IV (EL9C4)',
#  'Making Connections IV (EL9C4)',
#  'Making Connection I (EL9CN)',
#  'Making Connection I (EL9CN)',
#  'General Employability Skills (EL9GE)',
#  'General Employability Skills (EL9GE)',
#  'Lifetime Nutrition & Wellness (EL9LN)',
#  'Method of Academic Success (EL9MP)',
#  'Method Academic Success (EL9MP)',
#  'Vocational Experience I (EL9V1)',
#  'Vocational Experience I (EL9V1)',
#  'Vocational Experience II (EL9V2)',
#  'Vocational Experience II (EL9V2)',
#  'Technical Theater I (FA11T)',
#  'Technical Theater I (FA11T)',
#  'Technical Theater II (FA12T)',
#  'Technical Theater II (FA12T)',
#  'Technical Theater III (FA13T)',
#  'Technical Theater III (FA13T)',
#  'Tech Theater IV (FA14T)',
#  'Tech Theater IV (FA14T)',
#  'Art I (FA1A1)',
#  'Art I (FA1A1)',
#  'Art II Ceramics (FA1AC)',
#  'Art II Ceramics (FA1AC)',
#  'Art II Drawing (FA1AD)',
#  'Art II Drawing (FA1AD)',
#  'Art II Digital Art & Media I (FA1AE)',
#  'Art II Digital Art & Media I (FA1AE)',
#  'Art II Jewelry (FA1AJ)',
#  'Art II Jewelry (FA1AJ)',
#  'Art II Painting (FA1AP)',
#  'Art II Painting (FA1AP)',
#  'Art II Sculpture (FA1AS)',
#  'Art II Sculpture (FA1AS)',
#  'Band (FA1BN)',
#  'Band (FA1BN)',
#  'Art III Ceramics II (FA1C3)',
#  'Art III Ceramics II (FA1C3)',
#  'Art IV Ceramics (FA1C4)',
#  'Art IV Ceramics (FA1C4)',
#  'Chorale Choir (FA1CC)',
#  'Chorale Choir (FA1CC)',
#  'Color Guard-Dance (FA1CG)',
#  'Color Guar-Dance (FA1CG)',
#  "Men's Choir (FA1CM)",
#  "Men's Choir (FA1CM)",
#  'Dance I (FA1D1)',
#  'Dance I (FA1D1)',
#  'Dance II (FA1D2)',
#  'Dance II (FA1D2)',
#  'Dance III (FA1D3)',
#  'Dance III (FA1D3)',
#  'Dance IV (FA1D4)',
#  'Dance IV (FA1D4)',
#  'Encore Choir (FA1EC)',
#  'Encore Choir (FA1EC)',
#  'Jazz Band 10 (FA1J0)',
#  'Jazz Band 10 (FA1J0)',
#  'Jazz Band 11 (FA1J1)',
#  'Jazz Band 11 (FA1J1)',
#  'Jazz Band 12 (FA1J2)',
#  'Jazz Band 12 (FA1J2)',
#  'Art III Jewelry (FA1J3)',
#  'Art III Jewelry (FA1J3)',
#  'Art IV Jewelry III (FA1J4)',
#  'Art IV Jewelry III (FA1J4)',
#  'Art III Digital Art & Media II (FA1M3)',
#  'Art III Digital Art & Media II (FA1M3)',
#  'Art IV Digital Art & Media III (FA1M4)',
#  'Art IV Digital Art & Media III (FA1M4)',
#  'Music Theory I (FA1MT)',
#  'Music Theory I (FA1MT)',
#  'Art III Painting II (FA1P3)',
#  'Art III Painting II (FA1P3)',
#  'Art IV Painting (FA1P4)',
#  'Art IV Painting (FA1P4)',
#  'Theater Arts I (FA1T1)',
#  'Theater Arts I (FA1T1)',
#  'Theater Arts II (FA1T2)',
#  'Theater Arts II (FA1T2)',
#  'Theater Arts III (FA1T3)',
#  'Theater Arts III (FA1T3)',
#  'Theater Arts IV (FA1T4)',
#  'Theater Arts IV (FA1T4)',
#  'Theatre Production I (FA1TP)',
#  'Theatre Production 1 (FA1TP)',
#  'Treble Select (FA1TS)',
#  'Treble Select (FA1TS)',
#  'Art I Advanced (FA2A1)',
#  'Art I Advanced (FA2A1)',
#  'Art II Drawing Advanced (FA2DR)',
#  'Art II Drawing Advanced (FA2DR)',
#  'AP Art History (FA3AH)',
#  'AP Art History (FA3AH)',
#  'AP Art Drawing Portfolio (FA3DR)',
#  'AP Art Drawing Portfolio (FA3DR)',
#  'AP Music Theory (FA3MT)',
#  'AP Music Theory (FA3MT)',
#  'AP Art 2-D Design Portfolio (FA3P2)',
#  'AP Art 2-D Design Portfolio (FA3P2)',
#  'AP Art 3-D Design Portfolio (FA3P3)',
#  'AP Art 3-D Design Portfolio (FA3P3)',
#  'DC Art I Art Appreciation (FA5AP)',
#  'DC Art I Art Appreciation (FA5AP)',
#  'DC Art I Art Appreciation (FA5AP)',
#  'Art Applied (FA9AP)',
#  'Art Applied (FA9AP)',
#  'Wind Ensemble (FAB10)',
#  'Wind Ensemble (FAB10)',
#  'Wind Ensemble (FAB11)',
#  'Wind Ensemble (FAB11)',
#  'Wind Ensemble (FAB12)',
#  'Wind Ensemble (FAB12)',
#  'Wind Symphony (FAB20)',
#  'Wind Symphony (FAB20)',
#  'Wind Symphony (FAB21)',
#  'Wind Symphony (FAB21)',
#  'Wind Symphony (FAB22)',
#  'Wind Symphony (FAB22)',
#  'Symphonic I Band (FAB30)',
#  'Symphonic I Band (FAB30)',
#  'Symphonic I Band (FAB31)',
#  'Symphonic I Band (FAB31)',
#  'Symphonic I Band (FAB32)',
#  'Symphonic I Band (FAB32)',
#  'Symphonic II Band (FAB40)',
#  'Symphonic II Band (FAB40)',
#  'Symphonic II Band (FAB41)',
#  'Symphonic II Band (FAB41)',
#  'Symphonic II Band (FAB42)',
#  'Symphonic II Band (FAB42)',
#  'Symphonic III Band 10th (FAB50)',
#  'Symphonic III Band 10th (FAB50)',
#  'Symphonic III Band 11th (FAB51)',
#  'Symphonic III Band 11th (FAB51)',
#  'Symphonic III Band 12th (FAB52)',
#  'Symphonic III Band 12th (FAB52)',
#  'Concert I Band 10th (FAB60)',
#  'Concert I Band 10th (FAB60)',
#  'Concert I Band 11th (FAB61)',
#  'Concert I Band 11th (FAB61)',
#  'Concert I Band 12th (FAB62)',
#  'Concert I Band 12th (FAB62)',
#  'Concert II Band 10th (FAB70)',
#  'Concert II Band 10th (FAB70)',
#  'Concert II Band 11th (FAB71)',
#  'Concert II Band 11th (FAB71)',
#  'Concert II Band 12th (FAB72)',
#  'Concert II Band 12th (FAB72)',
#  'Percussion (FABP0)',
#  'Percussion (FABP0)',
#  'Percussion (FABP1)',
#  'Percussion (FABP1)',
#  'Percussion (FABP2)',
#  'Percussion (FABP2)',
#  'Chorale Choir 2 (FACC2)',
#  'Chorale Choir 2 (FACC2)',
#  'Chorale Choir 3 (FACC3)',
#  'Chorale Choir 3 (FACC3)',
#  'Chorale Choir 4 (FACC4)',
#  'Chorale Choir 4 (FACC4)',
#  'Eagle Select 2 (FACE2)',
#  'Eagle Select 2 (FACE2)',
#  'Eagle Select 3 (FACE3)',
#  'Eagle Select 3 (FACE3)',
#  'Eagle Select 4 (FACE4)',
#  'Eagle Select 4 (FACE4)',
#  'Color Guard 2 (FACG2)',
#  'Color Guard 2 (FACG2)',
#  'Color Guard 3 (FACG3)',
#  'Color Guard 3 (FACG3)',
#  'Color Guard 4 (FACG4)',
#  'Color Guard 4 (FACG4)',
#  "Men's Choir 2 (FACM2)",
#  "Men's Choir 2 (FACM2)",
#  "Men's Choir 3 (FACM3)",
#  "Men's Choir 3 (FACM3)",
#  "Men's Choir 4 (FACM4)",
#  "Men's Choir 4 (FACM4)",
#  'Treble Choir 2 (FACT2)',
#  'Treble Choir 2 (FACT2)',
#  'Treble Choir 3 (FACT3)',
#  'Treble Choir 3 (FACT3)',
#  'Treble Choir 4 (FACT4)',
#  'Treble Choir 4 (FACT4)',
#  'Mixed Choir 2 (FACX2)',
#  'Mixed Choir 2 (FACX2)',
#  'Mixed Choir 3 (FACX3)',
#  'Mixed Choir 3 (FACX3)',
#  'Mixed Choir 4 (FACX4)',
#  'Mixed Choir 4 (FACX4)',
#  'Encore Choir 2 (FAEC2)',
#  'Encore Choir 2 (FAEC2)',
#  'Encore Choir 3 (FAEC3)',
#  'Encore Choir 3 (FAEC3)',
#  'Encore Choir 4 (FAEC4)',
#  'Encore Choir 4 (FAEC4)',
#  'Sinfonia Orchestra I 10 (FAO30)',
#  'Sinfonia Orchestra I 10 (FAO30)',
#  'Sinfonia Orchestra I 11 (FAO31)',
#  'Sinfonia Orchestra I 11 (FAO31)',
#  'Sinfonia Orchestra I 12 (FAO32)',
#  'Sinfonia Orchestra I 12 (FAO32)',
#  'Sinfonia Orchestra II 10 (FAO40)',
#  'Sinfonia Orchestra II 10 (FAO40)',
#  'Sinfonia Orchestra II 11 (FAO41)',
#  'Sinfonia Orchestra II 11 (FAO41)',
#  'Sinfonia Orchestra II 12 (FAO42)',
#  'Sinfonia Orchestra II 12 (FAO42)',
#  'Concert Orchestra I 10 (FAO50)',
#  'Concert Orchestra I 10 (FAO50)',
#  'Concert Orchestra I 11 (FAO51)',
#  'Concert Orchestra I 11 (FAO51)',
#  'Concert Orchestra I 12 (FAO52)',
#  'Concert Orchestra I 12 (FAO52)',
#  'Concert Orchestra II 10 (FAO60)',
#  'Concert Orchestra II 10 (FAO60)',
#  'Concert Orchestra II 11 (FAO61)',
#  'Concert Orchestra II 11 (FAO61)',
#  'Concert Orchestra II 12 (FAO62)',
#  'Concert Orchestra II 12 (FAO62)',
#  'Silver Stars 1 (FASS1)',
#  'Silver Stars 1 (FASS1)',
#  'Silver Stars 2 (FASS2)',
#  'Silver Stars 2 (FASS2)',
#  'Silver Stars 3 (FASS3)',
#  'Silver Stars 3 (FASS3)',
#  'Tallenettes 1 (FATN1)',
#  'Tallenettes 1 (FATN1)',
#  'Tallenettes 2 (FATN2)',
#  'Tallenettes 2 (FATN2)',
#  'Tallenettes 3 (FATN3)',
#  'Tallenettes 3 (FATN3)',
#  'Tallenettes 4 (FATN4)',
#  'Tallenettes 4 (FATN4)',
#  'Theatre Production II (FATP2)',
#  'Theatre Production II (FATP2)',
#  'Theatre Production III (FATP3)',
#  'Theatre Production III (FATP3)',
#  'Theatre Production IV (FATP4)',
#  'Theatre Production IV (FATP4)',
#  'Treble Select 2 (FATS2)',
#  'Treble Select 2 (FATS2)',
#  'Treble Select 3 (FATS3)',
#  'Treble Select 3 (FATS3)',
#  'Treble Select 4 (FATS4)',
#  'Treble Select 4 (FATS4)',
#  'Advanced Culinary Arts (FC1AC)',
#  'Advanced Culinary Arts (FC1AC)',
#  'Culinary Arts (FC1CL)',
#  'Culinary Arts (FC1CL)',
#  'Human Growth and Development (FC1HG)',
#  'Human Growth and Development (FC1HG)',
#  'Hotel Management (FC1HM)',
#  'Hotel Management (FC1HM)',
#  'Hospitality Services (FC1HS)',
#  'Hospitality Services (FC1HS)',
#  'Intro Culinary Arts (FC1IC)',
#  'Intro Culinary Arts (FC1IC)',
#  'Instructional Practices (FC1IP)',
#  'Instructional Practices (FC1IP)',
#  'Practicum in Culinary Arts I (FC1PC)',
#  'Practicum in Culinary Arts I (FC1PC)',
#  'Prin\\/Education and Training (FC1PE)',
#  'Prin\\/Education and Training (FC1PE)',
#  'Practicum-HospitalityServicesI (FC1PH)',
#  'Practicum-HospitalityServicesI (FC1PH)',
#  'Practicum Education & Training (FC1T2)',
#  'Practicum Education & Training (FC1T2)',
#  'Culinary Arts (FC2CA)',
#  'Culinary Arts (FC2CA)',
#  'Hospitality Services (FC2HS)',
#  'Hospitality Services (FC2HS)',
#  'Prac Culinary Art 2 (FCPC2)',
#  'Prac Culinary Art 2 (FCPC2)',
#  'Pract\\/Hospitality Services II (FCPH2)',
#  'Pract\\/Hospitality Services II (FCPH2)',
#  'American Sign Language 1 (FL1A1)',
#  'American Sign Language 1 (FL1A1)',
#  'American Sign Language II (FL1A2)',
#  'American Sign Language II (FL1A2)',
#  'American Sign Language III (FL1A3)',
#  'American Sign Language III (FL1A3)',
#  'American Sign Language IV (FL1A4)',
#  'American Sign Language IV (FL1A4)',
#  'Chinese I (FL1C1)',
#  'Chinese I (FL1C1)',
#  'Chinese II (FL1C2)',
#  'Chinese II (FL1C2)',
#  'Chinese III (FL1C3)',
#  'Chinese III (FL1C3)',
#  'French I (FL1F1)',
#  'French I (FL1F1)',
#  'French II (FL1F2)',
#  'French II (FL1F2)',
#  'French II (FL1F2)',
#  'French II (FL1F2)',
#  'French III (FL1F3)',
#  'French III (FL1F3)',
#  'German I (FL1G1)',
#  'German I (FL1G1)',
#  'German II (FL1G2)',
#  'German II (FL1G2)',
#  'German III (FL1G3)',
#  'German III (FL1G3)',
#  'Spanish I (FL1S1)',
#  'Spanish I (FL1S1)',
#  'Spanish II (FL1S2)',
#  'Spanish II (FL1S2)',
#  'Spanish III (FL1S3)',
#  'Spanish III (FL1S3)',
#  'Chinese I Advanced (FL2C1)',
#  'Chinese I Advanced (FL2C1)',
#  'Chinese II Advanced (FL2C2)',
#  'Chinese II Advanced (FL2C2)',
#  'Chinese III Advanced (FL2C3)',
#  'Chinese III Advanced (FL2C3)',
#  'French II Advanced (FL2F2)',
#  'French II Advanced (FL2F2)',
#  'French III Advanced (FL2F3)',
#  'French III Advanced (FL2F3)',
#  'German I Advanced (FL2G1)',
#  'German I Advanced (FL2G1)',
#  'German II Advanced (FL2G2)',
#  'German II Advanced (FL2G2)',
#  'German III Advanced (FL2G3)',
#  'German III Advanced (FL2G3)',
#  'Spanish II Advanced (FL2S2)',
#  'Spanish II Advanced (FL2S2)',
#  'Spanish II Advanced (FL2S2)',
#  'Spanish III Advanced (FL2S3)',
#  'Spanish III Advanced (FL2S3)',
#  'Spanish III Native Spkr Adv (FL2SS)',
#  'AP French IV (FL3F4)',
#  'AP French IV (FL3F4)',
#  'AP Spanish IV (FL3S4)',
#  'AP Spanish IV (FL3S4)',
#  'Spanish IV Native Spkr AP (FL3SS)',
#  'Health I (HL1H1)',
#  'Health I (HL1H1)',
#  'Medical Terminology (HS1MT)',
#  'Medical Terminology (HS1MT)',
#  'Principles of Health Science (HS1PH)',
#  'Principles of Health Science (HS1PH)',
#  'Principles of Health Science (HS2PH)',
#  'Principles of Health Science (HS2PH)',
#  'Prac\\/Hlt\\/Sci-Pharmacy Tech (HS2PT)',
#  'Prac\\/Hlt\\/Sci-Pharmacy Tech (HS2PT)',
#  'Pathophysiology (HS2PY)',
#  'Pathophysiology (HS2PY)',
#  'DC Medical Terminology (HS5MT)',
#  'DC Medical Terminology (HS5MT)',
#  'DC Medical Terminology (HS5MT)',
#  'DC Medical Terminology (HS5MT)',
#  'IB Art Higher Level YR1 (IBAH1)',
#  'IB Art Higher Level YR1 (IBAH1)',
#  'IB Art Higher Level YR2 (IBAHL)',
#  'IB Art Higher Level YR2 (IBAHL)',
#  'IB Art Standard Level YR1 (IBAS1)',
#  'IB Art Standard Level YR1 (IBAS1)',
#  'IB Art Standard Level YR2 (IBASL)',
#  'IB Art Standard Level YR2 (IBASL)',
#  'IB Biology HL YR1 (IBBH1)',
#  'IB Biology HL YR1 (IBBH1)',
#  'IB Biology HL YR2 (IBBH2)',
#  'IB Biology HL YR2 (IBBH2)',
#  'IB Biology Standard Level (IBBSL)',
#  'IB Biology Standard Level (IBBSL)',
#  'IB Chemistry Higher Level YR1 (IBCH1)',
#  'IB Chemistry Higher Level YR1 (IBCH1)',
#  'IB Chemistry Higher Level YR2 (IBCH2)',
#  'IB Chemistry Higher Level YR2 (IBCH2)',
#  'IB Chinese Standard Level (IBCHI)',
#  'IB Chinese Standard Level (IBCHI)',
#  'IB Chemistry Standard Level (IBCSL)',
#  'IB Chemistry Standard Level (IBCSL)',
#  'IB French Higher Level YR1 (IBFH1)',
#  'IB French Higher Level YR1 (IBFH1)',
#  'IB French Higher Level Y2 (IBFH2)',
#  'IB French Higher Level YR2 (IBFH2)',
#  'IB French Standard Level YR1 (IBFS1)',
#  'IB French Standard Level YR1 (IBFS1)',
#  'IB French Standard Level YR2 (IBFS2)',
#  'IB French Standard Level YR2 (IBFS2)',
#  'IB German Standard Level (IBGER)',
#  'IB German Standard Level (IBGER)',
#  'IB History of Americas HL YR1 (IBHH1)',
#  'IB History of Americas HL YR1 (IBHH1)',
#  'IB History of Americas HL YR2 (IBHH2)',
#  'IB History of Americas HL YR2 (IBHH2)',
#  'IB Language Studies YR1 (IBLA1)',
#  'IB Language Studies YR1 (IBLA1)',
#  'IB Language Studies YR2 (IBLA2)',
#  'IB Language Studies YR2 (IBLA2)',
#  'IB GT Language Studies YR1 (IBLG1)',
#  'IB GT Language Studies YR1 (IBLG1)',
#  'IB GT Language Studies YR2 (IBLG2)',
#  'IB GT Language Studies YR2 (IBLG2)',
#  'IB Math Analysis HL YR1 (IBM1H)',
#  'IB Math Analysis HL YR1 (IBM1H)',
#  'IB Math Analysis SL YR1 (IBM1S)',
#  'IB Math Analysis SL YR1 (IBM1S)',
#  'IB Math Analysis HL YR2 (IBM2H)',
#  'IB Math Analysis HL YR2 (IBM2H)',
#  'IB Math Analysis SL YR2 (IBM2S)',
#  'IB Math Analysis SL YR2 (IBM2S)',
#  'IB Music Standard Level (IBMSL)',
#  'IB Music Standard Level (IBMSL)',
#  'IB Psychology Higher Level YR1 (IBPH1)',
#  'IB Psychology Higher Level YR1 (IBPH1)',
#  'IB Psychology Higher Level YR2 (IBPH2)',
#  'IB Psychology Higher Level YR2 (IBPH2)',
#  'IB Physics Standard Level (IBPHY)',
#  'IB Physics Standard Level (IBPHY)',
#  'IB Psychology Standard Level (IBPSL)',
#  'IB Psychology Standard Level (IBPSL)',
#  'IB Spanish Higher Level YR1 (IBSH1)',
#  'IB Spanish Higher Level YR1 (IBSH1)',
#  'IB Spanish Higher Level YR2 (IBSH2)',
#  'IB Spanish Higher Level YR2 (IBSH2)',
#  'IB Spanish Standard Level YR1 (IBSS1)',
#  'IB Spanish Standard Level YR1 (IBSS1)',
#  'IB Spanish Standard Level YR2 (IBSS2)',
#  'IB Spanish Standard Level YR2 (IBSS2)',
#  'IB Intro Theory Knowledge JR (IBTK1)',
#  'IB Intro Theory Knowledge JR (IBTK1)',
#  'IB Theory of Knowledge Seniors (IBTK2)',
#  'IB Theory of Knowledge Seniors (IBTK2)',
#  'English I (LA1E1)',
#  'English I (LA1E1)',
#  'English II (LA1E2)',
#  'English II (LA1E2)',
#  'English II (LA1E2)',
#  'English III (LA1E3)',
#  'English III (LA1E3)',
#  'English IV (LA1E4)',
#  'English IV (LA1E4)',
#  'Photojournalism (LA1PJ)',
#  'Photojournalism (LA1PJ)',
#  'English II Advanced (LA2E2)',
#  'English II Advanced (LA2E2)',
#  'English II Advanced GTPhoenix (LA2G2)',
#  'English II Advanced GTPhoenix (LA2G2)',
#  'AP English III (LA3E3)',
#  'AP English III (LA3E3)',
#  'AP English IV (LA3E4)',
#  'AP English IV (LA3E4)',
#  'AP-GT English III Phoenix (LA3G3)',
#  'AP-GT English III Phoenix (LA3G3)',
#  'AP-GT English IV Phoenix (LA3G4)',
#  'AP-GT English IV Phoenix (LA3G4)',
#  'DC Composition English 3F (LA5E3)',
#  'DC Composition English 3F (LA5E3)',
#  'DC Composition English 3F (LA5E3)',
#  'DC Composition English 3S (LA5E3)',
#  'DC Composition English 3S (LA5E3)',
#  'DC Composition English 3S (LA5E3)',
#  'DC Composition English 4 (LA5E4)',
#  'DC Composition English 4 (LA5E4)',
#  'DC Composition English 4 (LA5E4)',
#  'DC Composition English 4 (LA5E4)',
#  'DC World Literature II (LA5W2)',
#  'DC World Literature II (LA5W2)',
#  'DC World Literature I (LA5WL)',
#  'DC World Literature I (LA5WL)',
#  'ESOL 1 (LA8E1)',
#  'ESOL 1 (LA8E1)',
#  'English II (LA8E2)',
#  'English II (LA8E2)',
#  'English III (LA8E3)',
#  'English III (LA8E3)',
#  'English IV (LA8E4)',
#  'English IV (LA8E4)',
#  'ESOL II (LA8EL)',
#  'ESOL II (LA8EL)',
#  'Reading I (LA8R1)',
#  'Reading I (LA8R1)',
#  'Reading II (LA8R2)',
#  'Reading II (LA8R2)',
#  'Reading III (LA8R3)',
#  'Reading III (LA8R3)',
#  'Reading I (LA9R1)',
#  'Reading I (LA9R1)',
#  'Reading II (LA9R2)',
#  'Reading II (LA9R2)',
#  'Forensic Science (LW1FS)',
#  'Forensic Science (LW1FS)',
#  'Law Enforcement I (LW1L1)',
#  'Law Enforcement I (LW1L1)',
#  'PraLawPubSafeCorSec II (LW1P2)',
#  'PraLawPubSafeCorSec II (LW1P2)',
#  'PraLawPubSafeCorSec I (LW1PL)',
#  'PraLawPubSafeCorSec I (LW1PL)',
#  'Prin\\/Law,PubSafe,Correct,Secur (LW1PP)',
#  'Prin\\/Law,PubSafe,Correct,Secur (LW1PP)',
#  'English 1 M (LX1E1)',
#  'English 1 M (LX1E1)',
#  'English II M (LX1E2)',
#  'English II M (LX1E2)',
#  'English III M (LX1E3)',
#  'English III M (LX1E3)',
#  'English IV (LX1E4)',
#  'English IV (LX1E4)',
#  'English II ESSENTIAL (LX9E2)',
#  'English II ESSENTIAL (LX9E2)',
#  'English III ESSENTIAL (LX9E3)',
#  'English III ESSENTIAL (LX9E3)',
#  'English IV ESSENTIAL (LX9E4)',
#  'English IV ESSENTIAL (LX9E4)',
#  'English I FUNDAMENTAL (LY91E)',
#  'English I FUNDAMENTAL (LY91E)',
#  'English I FUNDAMENTAL (LY91E)',
#  'English I FUNDAMENTAL (LY91E)',
#  'English II FUNDAMENTAL (LY92E)',
#  'English II FUNDAMENTAL (LY92E)',
#  'English II FUNDAMENTAL (LY92E)',
#  'English II FUNDAMENTAL (LY92E)',
#  'English III FUNDAMENTAL (LY93E)',
#  'English III FUNDAMENTAL (LY93E)',
#  'English III FUNDAMENTAL (LY93E)',
#  'English III FUNDAMENTAL (LY93E)',
#  'English IV FUNDAMENTAL (LY94E)',
#  'English IV FUNDAMENTAL (LY94E)',
#  'English V FUNDAMENTAL (LY95E)',
#  'English V FUNDAMENTAL (LY95E)',
#  'English V FUNDAMENTAL (LY95E)',
#  'English V FUNDAMENTAL (LY95E)',
#  'English I Applications (LY9E1)',
#  'English I Applied (LY9E1)',
#  'English II Applied (LY9E2)',
#  'English II Applied (LY9E2)',
#  'English III Applied (LY9E3)',
#  'English III Applied (LY9E3)',
#  'English IV Applied (LY9E4)']

# %%
tmp=course_names[0].split('(')

# %%
tmp
# Out:
# ['Advanced Animal Science ', 'AG1AA)']

# %%
tmp[1]=tmp[1][:-1]

# %%
tmp
# Out:
# ['Advanced Animal Science ', 'AG1AA']

# %%
tmp2=(tmp[1],tmp[0])

# %%
tmp2
# Out:
# ('AG1AA', 'Advanced Animal Science ')

# %%
course_names.drop_duplicates(inplace=True)

# %%
course_names
# Out:
# 0            Advanced Animal Science (AG1AA)
# 2                     Equine Science (AG1EQ)
# 4                      Floral Design (AG1FL)
# 6      Prin Agric, Food, Natural Res (AG1FN)
# 8               Livestock Production (AG1LP)
#                        ...
# 687           English I Applications (LY9E1)
# 688                English I Applied (LY9E1)
# 689               English II Applied (LY9E2)
# 691              English III Applied (LY9E3)
# 693               English IV Applied (LY9E4)
# Name: description, Length: 343, dtype: object

# %%
course_tuple = []
for i in course_names:
    tmp=i.split('(')
    tmp[0]=tmp[0][:-1]
    tmp2=(tmp[0],tmp[0])
    course_tuple.append(tmp2)
#     print(course_tuple)
print(course_tuple)
# Out:
# [('Advanced Animal Science', 'Advanced Animal Science'), ('Equine Science', 'Equine Science'), ('Floral Design', 'Floral Design'), ('Prin Agric, Food, Natural Res', 'Prin Agric, Food, Natural Res'), ('Livestock Production', 'Livestock Production'), ('Ag Mechanical-Metal Technology', 'Ag Mechanical-Metal Technology'), ('Ag Mechanica-Metal Technology', 'Ag Mechanica-Metal Technology'), ('Math Applications Agriculture', 'Math Applications Agriculture'), ('Practicum-Ag-Mechanics', 'Practicum-Ag-Mechanics'), ('Small Animal Management', 'Small Animal Management'), ('Agricultrual Structure DesFab', 'Agricultrual Structure DesFab'), ('Prac Ag-Veterinary Med', 'Prac Ag-Veterinary Med'), ('Prac-Ag-Floral Design I', 'Prac-Ag-Floral Design I'), ('Veterinary Medical Application', 'Veterinary Medical Application'), ('Advance Music Band 10th', 'Advance Music Band 10th'), ('Advance Music Choir 10th', 'Advance Music Choir 10th'), ('Advance Music Orchestra 10th', 'Advance Music Orchestra 10th'), ('Advance Music Band 11th', 'Advance Music Band 11th'), ('Advance Music Band 12th', 'Advance Music Band 12th'), ('Advance Music Choir 11th', 'Advance Music Choir 11th'), ('Advance Music Choir 12th', 'Advance Music Choir 12th'), ('Advance Music Orchestra 11th', 'Advance Music Orchestra 11th'), ('Advance Music Orchestra 12th', 'Advance Music Orchestra 12th'), ('Accounting I', 'Accounting I'), ('Advertising', 'Advertising'), ('Banking and Financial Services', 'Banking and Financial Services'), ('Business Management', 'Business Management'), ('Entrepreneurship', 'Entrepreneurship'), ('Financial Mathematics', 'Financial Mathematics'), ('Fashion Marketing', 'Fashion Marketing'), ('Business Information Mgt I', 'Business Information Mgt I'), ('Business Information Mgt II', 'Business Information Mgt II'), ('Business Law', 'Business Law'), ('Practicum in Business Mgt I', 'Practicum in Business Mgt I'), ('Pri Business\\/Marketing\\/Finance', 'Pri Business\\/Marketing\\/Finance'), ('Sports Entertainment Marketing', 'Sports Entertainment Marketing'), ('Prac Business - Financial Serv', 'Prac Business - Financial Serv'), ('Prac Business Financial Serv', 'Prac Business Financial Serv'), ('DC Prin Financial Accounting', 'DC Prin Financial Accounting'), ('DC Prin Managerial Accounting', 'DC Prin Managerial Accounting'), ('DC Bus & Prof Communication', 'DC Bus & Prof Communication'), ('DC Business Principles', 'DC Business Principles'), ('Dollars & Sense', 'Dollars & Sense'), ('Money Matters', 'Money Matters'), ('Practicum Business Mgmt II', 'Practicum Business Mgmt II'), ('Debate 1', 'Debate 1'), ('Debate II', 'Debate II'), ('Journalism', 'Journalism'), ('Advanced Journalism News', 'Advanced Journalism News'), ('Advanced Journalism News 2', 'Advanced Journalism News 2'), ('Advanced Journalism News 3', 'Advanced Journalism News 3'), ('Advanced Journalism Yearbook', 'Advanced Journalism Yearbook'), ('Advanced Journalism Yearbook 2', 'Advanced Journalism Yearbook 2'), ('Advanced Journalism Yearbook 3', 'Advanced Journalism Yearbook 3'), ('Independent Study Journalism 2', 'Independent Study Journalism 2'), ('Independent Study Journalism 3', 'Independent Study Journalism 3'), ('Independent Study Journalism 1', 'Independent Study Journalism 1'), ('Independent Study Journalism', 'Independent Study Journalism'), ('Advanced JournalismNews 2 Edit', 'Advanced JournalismNews 2 Edit'), ('Advanced JournalismNews 3 Edit', 'Advanced JournalismNews 3 Edit'), ('Advanced Journalism Yrbk2 Edit', 'Advanced Journalism Yrbk2 Edit'), ('Advanced Journalism Yrbk3 Edit', 'Advanced Journalism Yrbk3 Edit'), ('DC Intro to Speech Comm', 'DC Intro to Speech Comm'), ('DC Bus & Prof Communication', 'DC Bus & Prof Communication'), ('DC Public Speaking', 'DC Public Speaking'), ('Aquatic Science', 'Aquatic Science'), ('Chemistry M', 'Chemistry M'), ('Environmental Science', 'Environmental Science'), ('IPC Modified', 'IPC Modified'), ('Chemistry ESS', 'Chemistry ESS'), ('Environmental Systems Applied', 'Envi ...
